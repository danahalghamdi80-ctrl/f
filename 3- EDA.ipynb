# %% [markdown]
# ARTI308 - Machine Learning
#
# # Lab 3: Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Students Performance Dataset

# %% [markdown]
# # 1- Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %% [markdown]
# This project applies Exploratory Data Analysis (EDA) techniques to the Students Performance dataset. The analysis includes data overview, summary statistics, visualization, correlation analysis, and time-based trends.

# %% [markdown]
# # 2- Data Loading (Option 1: Load Local CSV)

# %%
# Load Dataset

df = pd.read_csv("StudentsPerformance.csv")

# %% [markdown]
# # 3- Display First Rows

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# The dataset contains students' demographic information and their scores in math, reading, and writing.

# %% [markdown]
# # 4- Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   str
#  1   race/ethnicity               1000 non-null   str
#  2   parental level of education  1000 non-null   str
#  3   lunch                        1000 non-null   str
#  4   test preparation course      1000 non-null   str
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), str(5)
# memory usage: 62.6 KB

# %% [markdown]
# The dataset has no missing values and contains both categorical and numerical features.

# %% [markdown]
# # 5- Statistical Summary

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ### Descriptive Statistics
#
# The average math score is approximately 66.
# The average reading score is approximately 69.
# The average writing score is approximately 68.
#
# Reading scores have the highest average among the three subjects.

# %% [markdown]
# ## 6- Check Missing Values

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# ### Missing Values
#
# There are no missing values in the dataset.
# All 1000 records contain complete information.

# %% [markdown]
# ## 7- Check Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# The dataset contains no duplicated rows.

# %% [markdown]
# ## 8-Distribution of Math Score (Histogram)

# %%
plt.hist(df['math score'])
plt.title("Distribution of Math Score")
plt.xlabel("Math Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Most students scored between 60 and 80 in math.

# %% [markdown]
# #  9- Average Math Score by Gender (Bar Chart)

# %%
df.groupby('gender')['math score'].mean().plot(kind='bar')
plt.title("Average Math Score by Gender")
plt.ylabel("Average Math Score")
plt.show()

# %% [markdown]
# Male students slightly outperform female students in math on average.

# %% [markdown]
# ## 10- Reading vs Writing Score (Scatter Plot)

# %%
plt.scatter(df['reading score'], df['writing score'])
plt.title("Reading vs Writing Score")
plt.xlabel("Reading Score")
plt.ylabel("Writing Score")
plt.show()

# %% [markdown]
# There is a strong positive relationship between reading and writing scores.

# %% [markdown]
# ## 11- Correlation Between Subjects (Heatmap)

# %%
sns.heatmap(df[['math score','reading score','writing score']].corr(), annot=True)
plt.title("Correlation Between Subjects")
plt.show()

# %% [markdown]
# Reading and writing show the highest correlation among the three subjects.

# %% [markdown]
# ## 12- Math Score Distribution by Gender (Boxplot)

# %%
sns.boxplot(x='gender', y='math score', data=df)
plt.title("Math Score Distribution by Gender")
plt.show()

# %% [markdown]
# The boxplot highlights variation in math performance between genders.

# %% [markdown]
# # Final Conclusion

# %% [markdown]
# The analysis shows that gender and test preparation course influence student performance.
# Female students perform better in reading and writing, while male students perform better in math.
# Students who completed the preparation course achieved higher scores in all subjects.
#
# Overall, preparation and demographic factors play an important role in academic success.
